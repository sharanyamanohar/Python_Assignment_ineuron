# %% [markdown]
# # Sharanya Manohar
# # Python Advanced-1

# %% [markdown]
# Q1. What is the purpose of Python?
#
# Ans-Python is the programming Language used to built websites,software,automated task ,data analytics purpose,etc.Nowadays python is well used Programming language because it is very easy to code compared to other language.It can be used for any problem in which it is not generalised to particular problem statement.It is free to use,it supports object oriented programming language.It has lot of libraries,even it has lot of in built data structures.It uses AI,ML,data analytics ,data vizualization,etc and even there is widely application with python

# %% [markdown]
# Q2. Where does an inheritance search look for an attribute?
#
# Ans-Inheritance defines the class that inherit all the methods and properties from other classes as derived subclass.The nampespace constructed tree generally took:
# a)Instance-Instance attributes are generated by assignments to self attributes in methods.
# b)Class-Class attributes are generated by assignments in class statement.
# c)Superclass-Superclass are made by listing class in parentheses in a class statement header.
#
#  In Python, inheritance happens when an object is qualified, and involves searching an attribute definition tree.The expression object.atr where object is an instance or class object, Python searches the namespace tree at and above object, for the first attr it can find

# %% [markdown]
# Q3. How do you distinguish between a class object and an instance object?
#
# Ans-Class is the template for creating objects in a program,where the object is an instance of a class.The instance object that belongs to class.
# Every object has a type and the object types are created using class.Instance is an object that belongs to a class.
#
# for eg:for instance,list is a class in python

# %% [markdown]
# Q4. What makes the first argument in a class’s method function special?
#
# Ans-self is the first argument in a class method function that makes special

# %% [markdown]
# Q5. What is the purpose of the __init__ method?
#
# Ans-The __init__ method lets the class initialize the object's attributes and serves no other purpose. It is only used within classes.

# %% [markdown]
# Q6. What is the process for creating a class instance?
#
# Ans-By Instantiating a Class-a call to a constructor. The name of the constructor provides the name of the class to instantiate.
# Instance methods need a class instance and can access the instance through self . Class methods don't need a class instance.

# %% [markdown]
# Q7. What is the process for creating a class?
#
# Ans-a)Create a Class. To create a class
# b)Create Object.
# c)The self Parameter.
# d)Modify Object Properties.
# e)Delete Object Properties.
# f)Delete Objects.

# %% [markdown]
# Q8. How would you define the superclasses of a class?
#
# Ans-A superclass is the class from which many subclasses can be created. The subclasses inherit the characteristics of a superclass. The superclass is also known as the parent class or base class. In the above example, Vehicle is the Superclass and its subclasses are Car.The class from which a class inherits is called the parent or superclass. A class which inherits from a superclass is called a subclass, also called heir class or child class. Superclasses are sometimes called ancestors as well.
